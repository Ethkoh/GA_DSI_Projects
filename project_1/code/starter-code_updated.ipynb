# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# Define the problem you are finding answers for from the data given.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
# Import and read 2017 data
sat_17 = pd.read_csv('../data/sat_2017.csv')
act_17 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
# Display first 10 rows
sat_17[:10]
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# 8   468    950
# 9   497   1017

# %%
act_17[:10]
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
# Display summary statistics
sat_17.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
act_17.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer: States with high participation rates tend to have lower scores.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: ACT includes national score unlike SAT

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer: SAT and ACT are complement of each other. So knowing the main form of test choice in each state can explain certain low participation rates, and even lower scores.
#
# Minimum possible value for SAT is 400, and ACT is 1.
# Maximum possible value for SAT is 1600, and ACT is 36.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#replacing '20.2x' by '20.2' typo
act_17.loc[51,'Composite']=20.2
act_17[49:]
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6      20.2

# %%
#replacing '2.3' to '23.2' typo
act_17.loc[21,'Science']=23.2
act_17[19:24]
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 19      Louisiana          100%     19.4  18.8     19.8     19.6      19.5
# 20          Maine            8%     24.2  24.0     24.8     23.7      24.3
# 21       Maryland           28%     23.3  23.1     24.2     23.2      23.6
# 22  Massachusetts           29%     25.4  25.3     25.9     24.7      25.4
# 23       Michigan           29%     24.1  23.7     24.5     23.8      24.1

# %%
# check if act_17 now make sense
act_17.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.442308
# std     2.332132   1.963602   2.048672   1.723351
# min    16.300000  18.000000  18.100000  18.200000
# 25%    19.000000  19.400000  20.475000  19.975000
# 50%    20.550000  20.900000  21.700000  21.300000
# 75%    23.300000  23.100000  24.125000  23.200000
# max    25.500000  25.300000  26.000000  24.900000

# %%
# replace '52' to '524' typo
sat_17.loc[20,'Math']=524
sat_17[17:24]
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 17       Kentucky            4%                                 631   616
# 18      Louisiana            4%                                 611   586
# 19          Maine           95%                                 513   499
# 20       Maryland           69%                                 536   524
# 21  Massachusetts           76%                                 555   551
# 22       Michigan          100%                                 509   495
# 23      Minnesota            3%                                 644   651
#
#     Total
# 17   1247
# 18   1198
# 19   1012
# 20   1060
# 21   1107
# 22   1005
# 23   1295

# %%
# check if sat_17 now make sense
sat_17.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  556.882353  1126.098039
# std                             45.666901   47.121395    92.494812
# min                            482.000000  468.000000   950.000000
# 25%                            533.500000  523.500000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
sat_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: Participation and Composite should be float.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
# Change Composite and Participation from object to float
# Alternative: act_17['Participation']=act_17.apply(lambda x: float(x['Participation'].replace('%','')),axis=1)
# Alternative: act_17['Participation']=act_17['Participation'].replace('%','', regex=True).astype(float)
act_17.Participation=act_17.Participation.replace('%','', regex=True).astype(float)
act_17.Composite=act_17.Composite.astype(float)
sat_17.Participation=sat_17.Participation.replace('%','', regex=True).astype(float)

# %%
# Check data type if corrected
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
sat_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
# Display first 10 rows to check
act_17[:10]
# Out:
#                   State  Participation  English  Math  Reading  Science  \
# 0              National           60.0     20.3  20.7     21.4     21.0
# 1               Alabama          100.0     18.9  18.4     19.7     19.4
# 2                Alaska           65.0     18.7  19.8     20.4     19.9
# 3               Arizona           62.0     18.6  19.8     20.1     19.8
# 4              Arkansas          100.0     18.9  19.0     19.7     19.5
# 5            California           31.0     22.5  22.7     23.1     22.2
# 6              Colorado          100.0     20.1  20.3     21.2     20.9
# 7           Connecticut           31.0     25.5  24.6     25.6     24.6
# 8              Delaware           18.0     24.1  23.4     24.8     23.6
# 9  District of Columbia           32.0     24.4  23.5     24.9     23.5
#
#    Composite
# 0       21.0
# 1       19.2
# 2       19.8
# 3       19.7
# 4       19.4
# 5       22.8
# 6       20.8
# 7       25.2
# 8       24.1
# 9       24.2

# %%
sat_17[:10]
# Out:
#                   State  Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5.0                                 593
# 1                Alaska           38.0                                 547
# 2               Arizona           30.0                                 563
# 3              Arkansas            3.0                                 614
# 4            California           53.0                                 531
# 5              Colorado           11.0                                 606
# 6           Connecticut          100.0                                 530
# 7              Delaware          100.0                                 503
# 8  District of Columbia          100.0                                 482
# 9               Florida           83.0                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# 8   468    950
# 9   497   1017

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# fixed earlier

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# check by looking at summary statistics
sat_17.describe()
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      51.000000                           51.000000   51.000000
# mean       39.803922                          569.117647  556.882353
# std        35.276632                           45.666901   47.121395
# min         2.000000                          482.000000  468.000000
# 25%         4.000000                          533.500000  523.500000
# 50%        38.000000                          559.000000  548.000000
# 75%        66.000000                          613.000000  599.000000
# max       100.000000                          644.000000  651.000000
#
#              Total
# count    51.000000
# mean   1126.098039
# std      92.494812
# min     950.000000
# 25%    1055.500000
# 50%    1107.000000
# 75%    1212.000000
# max    1295.000000

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
# Check datatype now correct
sat_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
# Check datatype now correct
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# Remove first row that contains National statistics from act_17
act_17=act_17.drop([0])
act_17.head()
# Out:
#         State  Participation  English  Math  Reading  Science  Composite
# 1     Alabama          100.0     18.9  18.4     19.7     19.4       19.2
# 2      Alaska           65.0     18.7  19.8     20.4     19.9       19.8
# 3     Arizona           62.0     18.6  19.8     20.1     19.8       19.7
# 4    Arkansas          100.0     18.9  19.0     19.7     19.5       19.4
# 5  California           31.0     22.5  22.7     23.1     22.2       22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
# Rename columns to ensure no same name
sat_17 = sat_17.add_suffix('_SAT_17')
act_17 = act_17.add_suffix('_ACT_17')

# Rename back to 'State'
sat_17.rename(columns={"State_SAT_17": "State"},inplace=True)
act_17.rename(columns={"State_ACT_17": "State"},inplace=True)

# Merge act_17 and sat_17 on 'State'
combined_2017 = pd.merge(sat_17,act_17, how='left',on='State')

# Display result
combined_2017.head(10)
# Out:
#                   State  Participation_SAT_17  \
# 0               Alabama                   5.0
# 1                Alaska                  38.0
# 2               Arizona                  30.0
# 3              Arkansas                   3.0
# 4            California                  53.0
# 5              Colorado                  11.0
# 6           Connecticut                 100.0
# 7              Delaware                 100.0
# 8  District of Columbia                 100.0
# 9               Florida                  83.0
#
#    Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 0                                        593          572          1165
# 1                                        547          533          1080
# 2                                        563          553          1116
# 3                                        614          594          1208
# 4                                        531          524          1055
# 5                                        606          595          1201
# 6                                        530          512          1041
# 7                                        503          492           996
# 8                                        482          468           950
# 9                                        520          497          1017
#
#    Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 0                 100.0            18.9         18.4            19.7
# 1                  65.0            18.7         19.8            20.4
# 2                  62.0            18.6         19.8            20.1
# 3                 100.0            18.9         19.0            19.7
# 4                  31.0            22.5         22.7            23.1
# 5                 100.0            20.1         20.3            21.2
# 6                  31.0            25.5         24.6            25.6
# 7                  18.0            24.1         23.4            24.8
# 8                  32.0            24.4         23.5            24.9
# 9                  73.0            19.0         19.4            21.0
#
#    Science_ACT_17  Composite_ACT_17
# 0            19.4              19.2
# 1            19.9              19.8
# 2            19.8              19.7
# 3            19.5              19.4
# 4            22.2              22.8
# 5            20.9              20.8
# 6            24.6              25.2
# 7            23.6              24.1
# 8            23.5              24.2
# 9            19.4              19.8

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
# Export merged 2017 data
combined_2017.to_csv('combined_2017.csv',index=False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
# Import and read 2018 data
act_18=pd.read_csv('../data/act_2018_updated.csv')
sat_18=pd.read_csv('../data/sat_2018.csv')

# %%
# Display data
act_18.head()
# Out:
#         State  Percentage of Students Tested  Average Composite Score  \
# 0     Alabama                            100                     19.1
# 1      Alaska                             33                     20.8
# 2     Arizona                             66                     19.2
# 3    Arkansas                            100                     19.4
# 4  California                             27                     22.7
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
# 2                   18.2                19.4                   19.5
# 3                   19.1                18.9                   19.7
# 4                   22.5                22.5                   23.0
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# 2                   19.2
# 3                   19.4
# 4                   22.1

# %%
# Display summary statistics
act_18.describe()
# Out:
#        Percentage of Students Tested  Average Composite Score  \
# count                      51.000000                51.000000
# mean                       61.647059                21.486275
# std                        34.080976                 2.106278
# min                         7.000000                17.700000
# 25%                        28.500000                19.950000
# 50%                        66.000000                21.300000
# 75%                       100.000000                23.550000
# max                       100.000000                25.600000
#
#        Average English Score  Average Math Score  Average Reading Score  \
# count              51.000000           51.000000              51.000000
# mean               20.988235           21.125490              22.015686
# std                 2.446356            2.035765               2.167245
# min                16.600000           17.800000              18.000000
# 25%                19.100000           19.400000              20.450000
# 50%                20.200000           20.700000              21.600000
# 75%                23.700000           23.150000              24.100000
# max                26.000000           25.200000              26.100000
#
#        Average Science Score
# count              51.000000
# mean               21.345098
# std                 1.870114
# min                17.900000
# 25%                19.850000
# 50%                21.100000
# 75%                23.050000
# max                24.900000

# %%
act_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          51 non-null     object
#  1   Percentage of Students Tested  51 non-null     int64
#  2   Average Composite Score        51 non-null     float64
#  3   Average English Score          51 non-null     float64
#  4   Average Math Score             51 non-null     float64
#  5   Average Reading Score          51 non-null     float64
#  6   Average Science Score          51 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.9+ KB

# %%
sat_18.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_18.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
# Notice Participation is object type
sat_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# Change Participation from object to float
sat_18.Participation=sat_18.Participation.replace('%','', regex=True).astype(float)

# %%
# Check datatype now correct
sat_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
# Rename columns to ensure no same name
sat_18 = sat_18.add_suffix('_SAT_18')
act_18 = act_18.add_suffix('_ACT_18')

# Rename back to 'State'
sat_18.rename(columns={"State_SAT_18": "State"},inplace=True)
act_18.rename(columns={"State_ACT_18": "State"},inplace=True)

# Merge act_18 and sat_18 on 'State'
combined_2018 = pd.merge(sat_18,act_18, how='left',on='State')

# Display result
combined_2018.head(10)
# Out:
#                   State  Participation_SAT_18  \
# 0               Alabama                   6.0
# 1                Alaska                  43.0
# 2               Arizona                  29.0
# 3              Arkansas                   5.0
# 4            California                  60.0
# 5              Colorado                 100.0
# 6           Connecticut                 100.0
# 7              Delaware                 100.0
# 8  District of Columbia                  92.0
# 9               Florida                  56.0
#
#    Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 0                                        595          571          1166
# 1                                        562          544          1106
# 2                                        577          572          1149
# 3                                        592          576          1169
# 4                                        540          536          1076
# 5                                        519          506          1025
# 6                                        535          519          1053
# 7                                        505          492           998
# 8                                        497          480           977
# 9                                        550          549          1099
#
#    Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 0                                   100                            19.1
# 1                                    33                            20.8
# 2                                    66                            19.2
# 3                                   100                            19.4
# 4                                    27                            22.7
# 5                                    30                            23.9
# 6                                    26                            25.6
# 7                                    17                            23.2
# 8                                    32                            23.6
# 9                                    66                            19.9
#
#    Average English Score_ACT_18  Average Math Score_ACT_18  \
# 0                          18.9                       18.3
# 1                          19.8                       20.6
# 2                          18.2                       19.4
# 3                          19.1                       18.9
# 4                          22.5                       22.5
# 5                          23.9                       23.2
# 6                          26.0                       24.8
# 7                          23.7                       23.1
# 8                          23.7                       22.7
# 9                          19.2                       19.3
#
#    Average Reading Score_ACT_18  Average Science Score_ACT_18
# 0                          19.6                          19.0
# 1                          21.6                          20.7
# 2                          19.5                          19.2
# 3                          19.7                          19.4
# 4                          23.0                          22.1
# 5                          24.4                          23.5
# 6                          26.1                          24.9
# 7                          24.5                          23.4
# 8                          24.4                          23.0
# 9                          21.1                          19.5

# %%
# Merge combined_2017 and combined_2018 on 'State'
final = pd.merge(combined_2017,combined_2018, how='left',on='State')

# Display first 10 rows of combined result
final.head()
# Out:
#         State  Participation_SAT_17  \
# 0     Alabama                   5.0
# 1      Alaska                  38.0
# 2     Arizona                  30.0
# 3    Arkansas                   3.0
# 4  California                  53.0
#
#    Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 0                                        593          572          1165
# 1                                        547          533          1080
# 2                                        563          553          1116
# 3                                        614          594          1208
# 4                                        531          524          1055
#
#    Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 0                 100.0            18.9         18.4            19.7
# 1                  65.0            18.7         19.8            20.4
# 2                  62.0            18.6         19.8            20.1
# 3                 100.0            18.9         19.0            19.7
# 4                  31.0            22.5         22.7            23.1
#
#    Science_ACT_17  ...  Participation_SAT_18  \
# 0            19.4  ...                   6.0
# 1            19.9  ...                  43.0
# 2            19.8  ...                  29.0
# 3            19.5  ...                   5.0
# 4            22.2  ...                  60.0
#
#    Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 0                                        595          571          1166
# 1                                        562          544          1106
# 2                                        577          572          1149
# 3                                        592          576          1169
# 4                                        540          536          1076
#
#    Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 0                                   100                            19.1
# 1                                    33                            20.8
# 2                                    66                            19.2
# 3                                   100                            19.4
# 4                                    27                            22.7
#
#    Average English Score_ACT_18  Average Math Score_ACT_18  \
# 0                          18.9                       18.3
# 1                          19.8                       20.6
# 2                          18.2                       19.4
# 3                          19.1                       18.9
# 4                          22.5                       22.5
#
#    Average Reading Score_ACT_18  Average Science Score_ACT_18
# 0                          19.6                          19.0
# 1                          21.6                          20.7
# 2                          19.5                          19.2
# 3                          19.7                          19.4
# 4                          23.0                          22.1
#
# [5 rows x 21 columns]

# %%
# Export merged final data
final.to_csv('final.csv',index=False)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
# Summary statistics for both 2017 and 2018 data
final.describe().transpose()
# Out:
#                                            count         mean        std  \
# Participation_SAT_17                        51.0    39.803922  35.276632
# Evidence-Based Reading and Writing_SAT_17   51.0   569.117647  45.666901
# Math_SAT_17                                 51.0   556.882353  47.121395
# Total_SAT_17                                51.0  1126.098039  92.494812
# Participation_ACT_17                        51.0    65.254902  32.140842
# English_ACT_17                              51.0    20.931373   2.353677
# Math_ACT_17                                 51.0    21.182353   1.981989
# Reading_ACT_17                              51.0    22.013725   2.067271
# Science_ACT_17                              51.0    21.450980   1.739353
# Composite_ACT_17                            51.0    21.519608   2.020695
# Participation_SAT_18                        51.0    45.745098  37.314256
# Evidence-Based Reading and Writing_SAT_18   51.0   563.686275  47.502627
# Math_SAT_18                                 51.0   556.235294  47.772623
# Total_SAT_18                                51.0  1120.019608  94.155083
# Percentage of Students Tested_ACT_18        51.0    61.647059  34.080976
# Average Composite Score_ACT_18              51.0    21.486275   2.106278
# Average English Score_ACT_18                51.0    20.988235   2.446356
# Average Math Score_ACT_18                   51.0    21.125490   2.035765
# Average Reading Score_ACT_18                51.0    22.015686   2.167245
# Average Science Score_ACT_18                51.0    21.345098   1.870114
#
#                                              min      25%     50%      75%  \
# Participation_SAT_17                         2.0     4.00    38.0    66.00
# Evidence-Based Reading and Writing_SAT_17  482.0   533.50   559.0   613.00
# Math_SAT_17                                468.0   523.50   548.0   599.00
# Total_SAT_17                               950.0  1055.50  1107.0  1212.00
# Participation_ACT_17                         8.0    31.00    69.0   100.00
# English_ACT_17                              16.3    19.00    20.7    23.30
# Math_ACT_17                                 18.0    19.40    20.9    23.10
# Reading_ACT_17                              18.1    20.45    21.8    24.15
# Science_ACT_17                              18.2    19.95    21.3    23.20
# Composite_ACT_17                            17.8    19.80    21.4    23.60
# Participation_SAT_18                         2.0     4.50    52.0    77.50
# Evidence-Based Reading and Writing_SAT_18  480.0   534.50   552.0   610.50
# Math_SAT_18                                480.0   522.50   544.0   593.50
# Total_SAT_18                               977.0  1057.50  1098.0  1204.00
# Percentage of Students Tested_ACT_18         7.0    28.50    66.0   100.00
# Average Composite Score_ACT_18              17.7    19.95    21.3    23.55
# Average English Score_ACT_18                16.6    19.10    20.2    23.70
# Average Math Score_ACT_18                   17.8    19.40    20.7    23.15
# Average Reading Score_ACT_18                18.0    20.45    21.6    24.10
# Average Science Score_ACT_18                17.9    19.85    21.1    23.05
#
#                                               max
# Participation_SAT_17                        100.0
# Evidence-Based Reading and Writing_SAT_17   644.0
# Math_SAT_17                                 651.0
# Total_SAT_17                               1295.0
# Participation_ACT_17                        100.0
# English_ACT_17                               25.5
# Math_ACT_17                                  25.3
# Reading_ACT_17                               26.0
# Science_ACT_17                               24.9
# Composite_ACT_17                             25.5
# Participation_SAT_18                        100.0
# Evidence-Based Reading and Writing_SAT_18   643.0
# Math_SAT_18                                 655.0
# Total_SAT_18                               1298.0
# Percentage of Students Tested_ACT_18        100.0
# Average Composite Score_ACT_18               25.6
# Average English Score_ACT_18                 26.0
# Average Math Score_ACT_18                    25.2
# Average Reading Score_ACT_18                 26.1
# Average Science Score_ACT_18                 24.9

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   State                                      51 non-null     object
#  1   Participation_SAT_17                       51 non-null     float64
#  2   Evidence-Based Reading and Writing_SAT_17  51 non-null     int64
#  3   Math_SAT_17                                51 non-null     int64
#  4   Total_SAT_17                               51 non-null     int64
#  5   Participation_ACT_17                       51 non-null     float64
#  6   English_ACT_17                             51 non-null     float64
#  7   Math_ACT_17                                51 non-null     float64
#  8   Reading_ACT_17                             51 non-null     float64
#  9   Science_ACT_17                             51 non-null     float64
#  10  Composite_ACT_17                           51 non-null     float64
#  11  Participation_SAT_18                       51 non-null     float64
#  12  Evidence-Based Reading and Writing_SAT_18  51 non-null     int64
#  13  Math_SAT_18                                51 non-null     int64
#  14  Total_SAT_18                               51 non-null     int64
#  15  Percentage of Students Tested_ACT_18       51 non-null     int64
#  16  Average Composite Score_ACT_18             51 non-null     float64
#  17  Average English Score_ACT_18               51 non-null     float64
#  18  Average Math Score_ACT_18                  51 non-null     float64
#  19  Average Reading Score_ACT_18               51 non-null     float64
#  20  Average Science Score_ACT_18               51 non-null     float64
# dtypes: float64(13), int64(7), object(1)
# memory usage: 8.8+ KB

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def sd_calculate(x):
    summation = 0
    mean = np.mean(x)
    n = len(x)
    for i in x:
        summation += (i-mean)**2
    return int(round(np.sqrt(1/n * summation)))

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %% [markdown]
# Answer:

# %%
# Get the column names that will be used to find standard deviation
col = final.drop('State',axis=1).columns

# Apply sd_calculate function in dictionary comprehension
# to find standard deviation for the columns of the data
sd = {x: sd_calculate(final[x]) for x in col}

# Show sd dictionary
sd
# Out:
# {'Participation_SAT_17': 35,
#  'Evidence-Based Reading and Writing_SAT_17': 45,
#  'Math_SAT_17': 47,
#  'Total_SAT_17': 92,
#  'Participation_ACT_17': 32,
#  'English_ACT_17': 2,
#  'Math_ACT_17': 2,
#  'Reading_ACT_17': 2,
#  'Science_ACT_17': 2,
#  'Composite_ACT_17': 2,
#  'Participation_SAT_18': 37,
#  'Evidence-Based Reading and Writing_SAT_18': 47,
#  'Math_SAT_18': 47,
#  'Total_SAT_18': 93,
#  'Percentage of Students Tested_ACT_18': 34,
#  'Average Composite Score_ACT_18': 2,
#  'Average English Score_ACT_18': 2,
#  'Average Math Score_ACT_18': 2,
#  'Average Reading Score_ACT_18': 2,
#  'Average Science Score_ACT_18': 2}

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
### LOWEST AND HIGHEST PARTICIPATION RATES

# %%
# Sort to find lowest participation rates for SAT 2017

final.sort_values('Participation_SAT_17').head()
# North Dakota, Mississippi and Iowa lowest participation rates for SAT 2017 at 2%
# Out:
#            State  Participation_SAT_17  \
# 34  North Dakota                   2.0
# 24   Mississippi                   2.0
# 15          Iowa                   2.0
# 25      Missouri                   3.0
# 44          Utah                   3.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 34                                        635          621          1256
# 24                                        634          607          1242
# 15                                        641          635          1275
# 25                                        640          631          1271
# 44                                        624          614          1238
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 34                  98.0            19.0         20.4            20.5
# 24                 100.0            18.2         18.1            18.8
# 15                  67.0            21.2         21.3            22.6
# 25                 100.0            19.8         19.9            20.8
# 44                 100.0            19.5         19.9            20.8
#
#     Science_ACT_17  ...  Participation_SAT_18  \
# 34            20.6  ...                   2.0
# 24            18.8  ...                   3.0
# 15            22.1  ...                   3.0
# 25            20.5  ...                   4.0
# 44            20.6  ...                   4.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 34                                        640          643          1283
# 24                                        630          606          1236
# 15                                        634          631          1265
# 25                                        633          629          1262
# 44                                        480          530          1010
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 34                                    98                            20.3
# 24                                   100                            18.6
# 15                                    68                            21.8
# 25                                   100                            20.0
# 44                                   100                            20.4
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 34                          19.1                       20.3
# 24                          18.2                       18.1
# 15                          21.0                       21.2
# 25                          19.5                       19.7
# 44                          19.7                       19.9
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 34                          20.7                          20.5
# 24                          18.9                          18.6
# 15                          22.5                          22.0
# 25                          20.5                          20.0
# 44                          20.9                          20.5
#
# [5 rows x 21 columns]

# %%
# Sort to find highest participation rates for SAT 2017

final.sort_values('Participation_SAT_17',ascending=False).head()
#District of Columbia, Michigan, Connecticut and Delaware highest particpation rate for SAT 2017 at 100%
# Out:
#                    State  Participation_SAT_17  \
# 8   District of Columbia                 100.0
# 22              Michigan                 100.0
# 6            Connecticut                 100.0
# 7               Delaware                 100.0
# 29         New Hampshire                  96.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 8                                         482          468           950
# 22                                        509          495          1005
# 6                                         530          512          1041
# 7                                         503          492           996
# 29                                        532          520          1052
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 8                   32.0            24.4         23.5            24.9
# 22                  29.0            24.1         23.7            24.5
# 6                   31.0            25.5         24.6            25.6
# 7                   18.0            24.1         23.4            24.8
# 29                  18.0            25.4         25.1            26.0
#
#     Science_ACT_17  ...  Participation_SAT_18  \
# 8             23.5  ...                  92.0
# 22            23.8  ...                 100.0
# 6             24.6  ...                 100.0
# 7             23.6  ...                 100.0
# 29            24.9  ...                  96.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 8                                         497          480           977
# 22                                        511          499          1011
# 6                                         535          519          1053
# 7                                         505          492           998
# 29                                        535          528          1063
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 8                                     32                            23.6
# 22                                    22                            24.4
# 6                                     26                            25.6
# 7                                     17                            23.2
# 29                                    16                            25.1
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 8                           23.7                       22.7
# 22                          24.5                       23.9
# 6                           26.0                       24.8
# 7                           23.7                       23.1
# 29                          25.1                       24.7
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 8                           24.4                          23.0
# 22                          24.7                          23.9
# 6                           26.1                          24.9
# 7                           24.5                          23.4
# 29                          25.6                          24.4
#
# [5 rows x 21 columns]

# %%
# Sort to find lowest participation rates for SAT 2018

final.sort_values('Participation_SAT_18').head()
# North Dakota has lowest participation rates for SAT 2018 at 2%
# Out:
#            State  Participation_SAT_17  \
# 34  North Dakota                   2.0
# 50       Wyoming                   3.0
# 41  South Dakota                   3.0
# 27      Nebraska                   3.0
# 49     Wisconsin                   3.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 34                                        635          621          1256
# 50                                        626          604          1230
# 41                                        612          603          1216
# 27                                        629          625          1253
# 49                                        642          649          1291
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 34                  98.0            19.0         20.4            20.5
# 50                 100.0            19.4         19.8            20.8
# 41                  80.0            20.7         21.5            22.3
# 27                  84.0            20.9         20.9            21.9
# 49                 100.0            19.7         20.4            20.6
#
#     Science_ACT_17  ...  Participation_SAT_18  \
# 34            20.6  ...                   2.0
# 50            20.6  ...                   3.0
# 41            22.0  ...                   3.0
# 27            21.5  ...                   3.0
# 49            20.9  ...                   3.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 34                                        640          643          1283
# 50                                        633          625          1257
# 41                                        622          618          1240
# 27                                        629          623          1252
# 49                                        641          653          1294
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 34                                    98                            20.3
# 50                                   100                            20.0
# 41                                    77                            21.9
# 27                                   100                            20.1
# 49                                   100                            20.5
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 34                          19.1                       20.3
# 50                          19.0                       19.7
# 41                          20.8                       21.6
# 27                          19.4                       19.8
# 49                          19.8                       20.3
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 34                          20.7                          20.5
# 50                          20.6                          20.3
# 41                          22.4                          22.2
# 27                          20.4                          20.1
# 49                          20.6                          20.8
#
# [5 rows x 21 columns]

# %%
# Sort to find the highest participation rates for SAT 2018

final.sort_values('Participation_SAT_18',ascending=False).head(6)
#Colorado, Connecticut, Delaware, Michigan and Idaho have highest particpation rate for SAT 2018 at 100%
# Out:
#           State  Participation_SAT_17  \
# 5      Colorado                  11.0
# 6   Connecticut                 100.0
# 7      Delaware                 100.0
# 22     Michigan                 100.0
# 12        Idaho                  93.0
# 19        Maine                  95.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 5                                         606          595          1201
# 6                                         530          512          1041
# 7                                         503          492           996
# 22                                        509          495          1005
# 12                                        513          493          1005
# 19                                        513          499          1012
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 5                  100.0            20.1         20.3            21.2
# 6                   31.0            25.5         24.6            25.6
# 7                   18.0            24.1         23.4            24.8
# 22                  29.0            24.1         23.7            24.5
# 12                  38.0            21.9         21.8            23.0
# 19                   8.0            24.2         24.0            24.8
#
#     Science_ACT_17  ...  Participation_SAT_18  \
# 5             20.9  ...                 100.0
# 6             24.6  ...                 100.0
# 7             23.6  ...                 100.0
# 22            23.8  ...                 100.0
# 12            22.1  ...                 100.0
# 19            23.7  ...                  99.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 5                                         519          506          1025
# 6                                         535          519          1053
# 7                                         505          492           998
# 22                                        511          499          1011
# 12                                        508          493          1001
# 19                                        512          501          1013
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 5                                     30                            23.9
# 6                                     26                            25.6
# 7                                     17                            23.2
# 22                                    22                            24.4
# 12                                    36                            22.3
# 19                                     7                            24.0
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 5                           23.9                       23.2
# 6                           26.0                       24.8
# 7                           23.7                       23.1
# 22                          24.5                       23.9
# 12                          21.9                       21.6
# 19                          23.8                       23.6
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 5                           24.4                          23.5
# 6                           26.1                          24.9
# 7                           24.5                          23.4
# 22                          24.7                          23.9
# 12                          23.2                          22.1
# 19                          24.7                          23.4
#
# [6 rows x 21 columns]

# %%
# Sort to find lowest participation rates for ACT 2017

final.sort_values('Participation_ACT_17').head()
# Maine lowest participation rates for ACT 2017 at 8%
# Out:
#             State  Participation_SAT_17  \
# 19          Maine                  95.0
# 29  New Hampshire                  96.0
# 7        Delaware                 100.0
# 39   Rhode Island                  71.0
# 38   Pennsylvania                  65.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 19                                        513          499          1012
# 29                                        532          520          1052
# 7                                         503          492           996
# 39                                        539          524          1062
# 38                                        540          531          1071
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 19                   8.0            24.2         24.0            24.8
# 29                  18.0            25.4         25.1            26.0
# 7                   18.0            24.1         23.4            24.8
# 39                  21.0            24.0         23.3            24.7
# 38                  23.0            23.4         23.4            24.2
#
#     Science_ACT_17  ...  Participation_SAT_18  \
# 19            23.7  ...                  99.0
# 29            24.9  ...                  96.0
# 7             23.6  ...                 100.0
# 39            23.4  ...                  97.0
# 38            23.3  ...                  70.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 19                                        512          501          1013
# 29                                        535          528          1063
# 7                                         505          492           998
# 39                                        513          505          1018
# 38                                        547          539          1086
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 19                                     7                            24.0
# 29                                    16                            25.1
# 7                                     17                            23.2
# 39                                    15                            24.2
# 38                                    20                            23.5
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 19                          23.8                       23.6
# 29                          25.1                       24.7
# 7                           23.7                       23.1
# 39                          24.4                       23.6
# 38                          23.3                       23.2
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 19                          24.7                          23.4
# 29                          25.6                          24.4
# 7                           24.5                          23.4
# 39                          25.0                          23.5
# 38                          24.0                          23.1
#
# [5 rows x 21 columns]

# %%
# Sort to find highest participation rates for ACT 2017

final.sort_values('Participation_ACT_17',ascending=False).head(18)
#Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, North Carolina, Nevada, Montana, Mississippi, Minnesota, Louisiana, Missouri, Wyoming, Colorado and Arkansas highest particpation rate for ACT 2017 at 100%
# Out:
#              State  Participation_SAT_17  \
# 0          Alabama                   5.0
# 17        Kentucky                   4.0
# 49       Wisconsin                   3.0
# 44            Utah                   3.0
# 42       Tennessee                   5.0
# 40  South Carolina                  50.0
# 36        Oklahoma                   7.0
# 33  North Carolina                  49.0
# 28          Nevada                  26.0
# 26         Montana                  10.0
# 24     Mississippi                   2.0
# 23       Minnesota                   3.0
# 18       Louisiana                   4.0
# 25        Missouri                   3.0
# 50         Wyoming                   3.0
# 5         Colorado                  11.0
# 3         Arkansas                   3.0
# 34    North Dakota                   2.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 0                                         593          572          1165
# 17                                        631          616          1247
# 49                                        642          649          1291
# 44                                        624          614          1238
# 42                                        623          604          1228
# 40                                        543          521          1064
# 36                                        530          517          1047
# 33                                        546          535          1081
# 28                                        563          553          1116
# 26                                        605          591          1196
# 24                                        634          607          1242
# 23                                        644          651          1295
# 18                                        611          586          1198
# 25                                        640          631          1271
# 50                                        626          604          1230
# 5                                         606          595          1201
# 3                                         614          594          1208
# 34                                        635          621          1256
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 0                  100.0            18.9         18.4            19.7
# 17                 100.0            19.6         19.4            20.5
# 49                 100.0            19.7         20.4            20.6
# 44                 100.0            19.5         19.9            20.8
# 42                 100.0            19.5         19.2            20.1
# 40                 100.0            17.5         18.6            19.1
# 36                 100.0            18.5         18.8            20.1
# 33                 100.0            17.8         19.3            19.6
# 28                 100.0            16.3         18.0            18.1
# 26                 100.0            19.0         20.2            21.0
# 24                 100.0            18.2         18.1            18.8
# 23                 100.0            20.4         21.5            21.8
# 18                 100.0            19.4         18.8            19.8
# 25                 100.0            19.8         19.9            20.8
# 50                 100.0            19.4         19.8            20.8
# 5                  100.0            20.1         20.3            21.2
# 3                  100.0            18.9         19.0            19.7
# 34                  98.0            19.0         20.4            20.5
#
#     Science_ACT_17  ...  Participation_SAT_18  \
# 0             19.4  ...                   6.0
# 17            20.1  ...                   4.0
# 49            20.9  ...                   3.0
# 44            20.6  ...                   4.0
# 42            19.9  ...                   6.0
# 40            18.9  ...                  55.0
# 36            19.6  ...                   8.0
# 33            19.3  ...                  52.0
# 28            18.2  ...                  23.0
# 26            20.5  ...                  10.0
# 24            18.8  ...                   3.0
# 23            21.6  ...                   4.0
# 18            19.6  ...                   4.0
# 25            20.5  ...                   4.0
# 50            20.6  ...                   3.0
# 5             20.9  ...                 100.0
# 3             19.5  ...                   5.0
# 34            20.6  ...                   2.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 0                                         595          571          1166
# 17                                        630          618          1248
# 49                                        641          653          1294
# 44                                        480          530          1010
# 42                                        624          607          1231
# 40                                        547          523          1070
# 36                                        541          521          1062
# 33                                        554          543          1098
# 28                                        574          566          1140
# 26                                        606          592          1198
# 24                                        630          606          1236
# 23                                        643          655          1298
# 18                                        615          595          1210
# 25                                        633          629          1262
# 50                                        633          625          1257
# 5                                         519          506          1025
# 3                                         592          576          1169
# 34                                        640          643          1283
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 0                                    100                            19.1
# 17                                   100                            20.2
# 49                                   100                            20.5
# 44                                   100                            20.4
# 42                                   100                            19.6
# 40                                   100                            18.3
# 36                                   100                            19.3
# 33                                   100                            19.1
# 28                                   100                            17.7
# 26                                   100                            20.0
# 24                                   100                            18.6
# 23                                    99                            21.3
# 18                                   100                            19.2
# 25                                   100                            20.0
# 50                                   100                            20.0
# 5                                     30                            23.9
# 3                                    100                            19.4
# 34                                    98                            20.3
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 0                           18.9                       18.3
# 17                          19.9                       19.7
# 49                          19.8                       20.3
# 44                          19.7                       19.9
# 42                          19.4                       19.1
# 40                          17.3                       18.2
# 36                          18.4                       18.8
# 33                          18.0                       19.3
# 28                          16.6                       17.8
# 26                          18.7                       19.9
# 24                          18.2                       18.1
# 23                          20.2                       21.4
# 18                          19.0                       18.5
# 25                          19.5                       19.7
# 50                          19.0                       19.7
# 5                           23.9                       23.2
# 3                           19.1                       18.9
# 34                          19.1                       20.3
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 0                           19.6                          19.0
# 17                          20.8                          20.1
# 49                          20.6                          20.8
# 44                          20.9                          20.5
# 42                          19.9                          19.6
# 40                          18.6                          18.5
# 36                          20.1                          19.4
# 33                          19.5                          19.2
# 28                          18.0                          17.9
# 26                          20.7                          20.0
# 24                          18.9                          18.6
# 23                          21.7                          21.4
# 18                          19.6                          19.1
# 25                          20.5                          20.0
# 50                          20.6                          20.3
# 5                           24.4                          23.5
# 3                           19.7                          19.4
# 34                          20.7                          20.5
#
# [18 rows x 21 columns]

# %%
# Sort to find lowest participation rates for ACT 2018

final.sort_values('Percentage of Students Tested_ACT_18').head()
# Maine has lowest participation rates for ACT 2018 at 7%
# Out:
#             State  Participation_SAT_17  \
# 19          Maine                  95.0
# 39   Rhode Island                  71.0
# 29  New Hampshire                  96.0
# 7        Delaware                 100.0
# 38   Pennsylvania                  65.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 19                                        513          499          1012
# 39                                        539          524          1062
# 29                                        532          520          1052
# 7                                         503          492           996
# 38                                        540          531          1071
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 19                   8.0            24.2         24.0            24.8
# 39                  21.0            24.0         23.3            24.7
# 29                  18.0            25.4         25.1            26.0
# 7                   18.0            24.1         23.4            24.8
# 38                  23.0            23.4         23.4            24.2
#
#     Science_ACT_17  ...  Participation_SAT_18  \
# 19            23.7  ...                  99.0
# 39            23.4  ...                  97.0
# 29            24.9  ...                  96.0
# 7             23.6  ...                 100.0
# 38            23.3  ...                  70.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 19                                        512          501          1013
# 39                                        513          505          1018
# 29                                        535          528          1063
# 7                                         505          492           998
# 38                                        547          539          1086
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 19                                     7                            24.0
# 39                                    15                            24.2
# 29                                    16                            25.1
# 7                                     17                            23.2
# 38                                    20                            23.5
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 19                          23.8                       23.6
# 39                          24.4                       23.6
# 29                          25.1                       24.7
# 7                           23.7                       23.1
# 38                          23.3                       23.2
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 19                          24.7                          23.4
# 39                          25.0                          23.5
# 29                          25.6                          24.4
# 7                           24.5                          23.4
# 38                          24.0                          23.1
#
# [5 rows x 21 columns]

# %%
# Sort to find highest participation rates for ACT 2018

final.sort_values('Percentage of Students Tested_ACT_18',ascending=False).head(18)
# Alabama,Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, Ohio, North Carolina, Nevada, Nebraska, Montana, Mississippi, Louisiana, Missouri, Wyoming and Arkansas 
# have highest particpation rate for ACT 2018 at 100%
# Out:
#              State  Participation_SAT_17  \
# 0          Alabama                   5.0
# 17        Kentucky                   4.0
# 49       Wisconsin                   3.0
# 44            Utah                   3.0
# 42       Tennessee                   5.0
# 40  South Carolina                  50.0
# 36        Oklahoma                   7.0
# 35            Ohio                  12.0
# 33  North Carolina                  49.0
# 28          Nevada                  26.0
# 27        Nebraska                   3.0
# 26         Montana                  10.0
# 24     Mississippi                   2.0
# 18       Louisiana                   4.0
# 25        Missouri                   3.0
# 50         Wyoming                   3.0
# 3         Arkansas                   3.0
# 23       Minnesota                   3.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 0                                         593          572          1165
# 17                                        631          616          1247
# 49                                        642          649          1291
# 44                                        624          614          1238
# 42                                        623          604          1228
# 40                                        543          521          1064
# 36                                        530          517          1047
# 35                                        578          570          1149
# 33                                        546          535          1081
# 28                                        563          553          1116
# 27                                        629          625          1253
# 26                                        605          591          1196
# 24                                        634          607          1242
# 18                                        611          586          1198
# 25                                        640          631          1271
# 50                                        626          604          1230
# 3                                         614          594          1208
# 23                                        644          651          1295
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 0                  100.0            18.9         18.4            19.7
# 17                 100.0            19.6         19.4            20.5
# 49                 100.0            19.7         20.4            20.6
# 44                 100.0            19.5         19.9            20.8
# 42                 100.0            19.5         19.2            20.1
# 40                 100.0            17.5         18.6            19.1
# 36                 100.0            18.5         18.8            20.1
# 35                  75.0            21.2         21.6            22.5
# 33                 100.0            17.8         19.3            19.6
# 28                 100.0            16.3         18.0            18.1
# 27                  84.0            20.9         20.9            21.9
# 26                 100.0            19.0         20.2            21.0
# 24                 100.0            18.2         18.1            18.8
# 18                 100.0            19.4         18.8            19.8
# 25                 100.0            19.8         19.9            20.8
# 50                 100.0            19.4         19.8            20.8
# 3                  100.0            18.9         19.0            19.7
# 23                 100.0            20.4         21.5            21.8
#
#     Science_ACT_17  ...  Participation_SAT_18  \
# 0             19.4  ...                   6.0
# 17            20.1  ...                   4.0
# 49            20.9  ...                   3.0
# 44            20.6  ...                   4.0
# 42            19.9  ...                   6.0
# 40            18.9  ...                  55.0
# 36            19.6  ...                   8.0
# 35            22.0  ...                  18.0
# 33            19.3  ...                  52.0
# 28            18.2  ...                  23.0
# 27            21.5  ...                   3.0
# 26            20.5  ...                  10.0
# 24            18.8  ...                   3.0
# 18            19.6  ...                   4.0
# 25            20.5  ...                   4.0
# 50            20.6  ...                   3.0
# 3             19.5  ...                   5.0
# 23            21.6  ...                   4.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 0                                         595          571          1166
# 17                                        630          618          1248
# 49                                        641          653          1294
# 44                                        480          530          1010
# 42                                        624          607          1231
# 40                                        547          523          1070
# 36                                        541          521          1062
# 35                                        552          547          1099
# 33                                        554          543          1098
# 28                                        574          566          1140
# 27                                        629          623          1252
# 26                                        606          592          1198
# 24                                        630          606          1236
# 18                                        615          595          1210
# 25                                        633          629          1262
# 50                                        633          625          1257
# 3                                         592          576          1169
# 23                                        643          655          1298
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 0                                    100                            19.1
# 17                                   100                            20.2
# 49                                   100                            20.5
# 44                                   100                            20.4
# 42                                   100                            19.6
# 40                                   100                            18.3
# 36                                   100                            19.3
# 35                                   100                            20.3
# 33                                   100                            19.1
# 28                                   100                            17.7
# 27                                   100                            20.1
# 26                                   100                            20.0
# 24                                   100                            18.6
# 18                                   100                            19.2
# 25                                   100                            20.0
# 50                                   100                            20.0
# 3                                    100                            19.4
# 23                                    99                            21.3
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 0                           18.9                       18.3
# 17                          19.9                       19.7
# 49                          19.8                       20.3
# 44                          19.7                       19.9
# 42                          19.4                       19.1
# 40                          17.3                       18.2
# 36                          18.4                       18.8
# 35                          19.3                       20.3
# 33                          18.0                       19.3
# 28                          16.6                       17.8
# 27                          19.4                       19.8
# 26                          18.7                       19.9
# 24                          18.2                       18.1
# 18                          19.0                       18.5
# 25                          19.5                       19.7
# 50                          19.0                       19.7
# 3                           19.1                       18.9
# 23                          20.2                       21.4
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 0                           19.6                          19.0
# 17                          20.8                          20.1
# 49                          20.6                          20.8
# 44                          20.9                          20.5
# 42                          19.9                          19.6
# 40                          18.6                          18.5
# 36                          20.1                          19.4
# 35                          20.8                          20.4
# 33                          19.5                          19.2
# 28                          18.0                          17.9
# 27                          20.4                          20.1
# 26                          20.7                          20.0
# 24                          18.9                          18.6
# 18                          19.6                          19.1
# 25                          20.5                          20.0
# 50                          20.6                          20.3
# 3                           19.7                          19.4
# 23                          21.7                          21.4
#
# [18 rows x 21 columns]

# %%
### LOWEST AND HIGHEST MEAN TOTAL/COMPOSITE SCORE

# %%
# Sort to find lowest mean total/composite scores for SAT 2017

final.sort_values('Total_SAT_17').head(3)
# District of Columbia has the lowest mean total for SAT 2017 at 950
# Out:
#                    State  Participation_SAT_17  \
# 8   District of Columbia                 100.0
# 7               Delaware                 100.0
# 12                 Idaho                  93.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 8                                         482          468           950
# 7                                         503          492           996
# 12                                        513          493          1005
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 8                   32.0            24.4         23.5            24.9
# 7                   18.0            24.1         23.4            24.8
# 12                  38.0            21.9         21.8            23.0
#
#     Science_ACT_17  ...  Participation_SAT_18  \
# 8             23.5  ...                  92.0
# 7             23.6  ...                 100.0
# 12            22.1  ...                 100.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 8                                         497          480           977
# 7                                         505          492           998
# 12                                        508          493          1001
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 8                                     32                            23.6
# 7                                     17                            23.2
# 12                                    36                            22.3
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 8                           23.7                       22.7
# 7                           23.7                       23.1
# 12                          21.9                       21.6
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 8                           24.4                          23.0
# 7                           24.5                          23.4
# 12                          23.2                          22.1
#
# [3 rows x 21 columns]

# %%
# Sort to find highest mean total/composite scores for SAT 2017

final.sort_values('Total_SAT_17',ascending=False).head(3)
# Minnesota has the highest mean total for SAT 2017 at 1295
# Out:
#         State  Participation_SAT_17  \
# 23  Minnesota                   3.0
# 49  Wisconsin                   3.0
# 15       Iowa                   2.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 23                                        644          651          1295
# 49                                        642          649          1291
# 15                                        641          635          1275
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 23                 100.0            20.4         21.5            21.8
# 49                 100.0            19.7         20.4            20.6
# 15                  67.0            21.2         21.3            22.6
#
#     Science_ACT_17  ...  Participation_SAT_18  \
# 23            21.6  ...                   4.0
# 49            20.9  ...                   3.0
# 15            22.1  ...                   3.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 23                                        643          655          1298
# 49                                        641          653          1294
# 15                                        634          631          1265
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 23                                    99                            21.3
# 49                                   100                            20.5
# 15                                    68                            21.8
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 23                          20.2                       21.4
# 49                          19.8                       20.3
# 15                          21.0                       21.2
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 23                          21.7                          21.4
# 49                          20.6                          20.8
# 15                          22.5                          22.0
#
# [3 rows x 21 columns]

# %%
# Sort to find lowest mean total/composite scores for SAT 2018

final.sort_values('Total_SAT_18').head(3)
# District of Columbia has the lowest mean total for SAT 2018 at 977
# Out:
#                    State  Participation_SAT_17  \
# 8   District of Columbia                 100.0
# 7               Delaware                 100.0
# 48         West Virginia                  14.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 8                                         482          468           950
# 7                                         503          492           996
# 48                                        558          528          1086
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 8                   32.0            24.4         23.5            24.9
# 7                   18.0            24.1         23.4            24.8
# 48                  69.0            20.0         19.4            21.2
#
#     Science_ACT_17  ...  Participation_SAT_18  \
# 8             23.5  ...                  92.0
# 7             23.6  ...                 100.0
# 48            20.5  ...                  28.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 8                                         497          480           977
# 7                                         505          492           998
# 48                                        513          486           999
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 8                                     32                            23.6
# 7                                     17                            23.2
# 48                                    65                            20.3
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 8                           23.7                       22.7
# 7                           23.7                       23.1
# 48                          19.8                       19.4
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 8                           24.4                          23.0
# 7                           24.5                          23.4
# 48                          21.3                          20.4
#
# [3 rows x 21 columns]

# %%
# Sort to find highest mean total/composite scores for SAT 2018

final.sort_values('Total_SAT_18',ascending=False).head(3)
# Minnesota has the highest mean total for SAT 2018 at 1298
# Out:
#            State  Participation_SAT_17  \
# 23     Minnesota                   3.0
# 49     Wisconsin                   3.0
# 34  North Dakota                   2.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 23                                        644          651          1295
# 49                                        642          649          1291
# 34                                        635          621          1256
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 23                 100.0            20.4         21.5            21.8
# 49                 100.0            19.7         20.4            20.6
# 34                  98.0            19.0         20.4            20.5
#
#     Science_ACT_17  ...  Participation_SAT_18  \
# 23            21.6  ...                   4.0
# 49            20.9  ...                   3.0
# 34            20.6  ...                   2.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 23                                        643          655          1298
# 49                                        641          653          1294
# 34                                        640          643          1283
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 23                                    99                            21.3
# 49                                   100                            20.5
# 34                                    98                            20.3
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 23                          20.2                       21.4
# 49                          19.8                       20.3
# 34                          19.1                       20.3
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 23                          21.7                          21.4
# 49                          20.6                          20.8
# 34                          20.7                          20.5
#
# [3 rows x 21 columns]

# %%
# Sort to find lowest mean total/composite scores for ACT 2017

pd.set_option('display.max_columns', 100)
final.sort_values('Composite_ACT_17').head(3)
# Nevada has the lowest mean composite for ACT 2017 at 17.8
# Out:
#              State  Participation_SAT_17  \
# 28          Nevada                  26.0
# 24     Mississippi                   2.0
# 40  South Carolina                  50.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 28                                        563          553          1116
# 24                                        634          607          1242
# 40                                        543          521          1064
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 28                 100.0            16.3         18.0            18.1
# 24                 100.0            18.2         18.1            18.8
# 40                 100.0            17.5         18.6            19.1
#
#     Science_ACT_17  Composite_ACT_17  Participation_SAT_18  \
# 28            18.2              17.8                  23.0
# 24            18.8              18.6                   3.0
# 40            18.9              18.7                  55.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 28                                        574          566          1140
# 24                                        630          606          1236
# 40                                        547          523          1070
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 28                                   100                            17.7
# 24                                   100                            18.6
# 40                                   100                            18.3
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 28                          16.6                       17.8
# 24                          18.2                       18.1
# 40                          17.3                       18.2
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 28                          18.0                          17.9
# 24                          18.9                          18.6
# 40                          18.6                          18.5

# %%
# Sort to find highest mean total/composite scores for ACT 2017

final.sort_values('Composite_ACT_17',ascending=False).head(4)
# New Hampshire has the highest mean composite for ACT 2017 at 25.5
# Massachusetts and Connecticut following closely behind at 25 also.
# Out:
#             State  Participation_SAT_17  \
# 29  New Hampshire                  96.0
# 21  Massachusetts                  76.0
# 6     Connecticut                 100.0
# 19          Maine                  95.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 29                                        532          520          1052
# 21                                        555          551          1107
# 6                                         530          512          1041
# 19                                        513          499          1012
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 29                  18.0            25.4         25.1            26.0
# 21                  29.0            25.4         25.3            25.9
# 6                   31.0            25.5         24.6            25.6
# 19                   8.0            24.2         24.0            24.8
#
#     Science_ACT_17  Composite_ACT_17  Participation_SAT_18  \
# 29            24.9              25.5                  96.0
# 21            24.7              25.4                  80.0
# 6             24.6              25.2                 100.0
# 19            23.7              24.3                  99.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 29                                        535          528          1063
# 21                                        562          563          1125
# 6                                         535          519          1053
# 19                                        512          501          1013
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 29                                    16                            25.1
# 21                                    25                            25.5
# 6                                     26                            25.6
# 19                                     7                            24.0
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 29                          25.1                       24.7
# 21                          25.5                       25.2
# 6                           26.0                       24.8
# 19                          23.8                       23.6
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 29                          25.6                          24.4
# 21                          25.9                          24.7
# 6                           26.1                          24.9
# 19                          24.7                          23.4

# %%
# Sort to find lowest mean total/composite scores for ACT 2018

final.sort_values('Average Composite Score_ACT_18').head(3)
# Nevada has the lowest mean composite for ACT 2018 at 17.7
# Out:
#              State  Participation_SAT_17  \
# 28          Nevada                  26.0
# 40  South Carolina                  50.0
# 24     Mississippi                   2.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 28                                        563          553          1116
# 40                                        543          521          1064
# 24                                        634          607          1242
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 28                 100.0            16.3         18.0            18.1
# 40                 100.0            17.5         18.6            19.1
# 24                 100.0            18.2         18.1            18.8
#
#     Science_ACT_17  Composite_ACT_17  Participation_SAT_18  \
# 28            18.2              17.8                  23.0
# 40            18.9              18.7                  55.0
# 24            18.8              18.6                   3.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 28                                        574          566          1140
# 40                                        547          523          1070
# 24                                        630          606          1236
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 28                                   100                            17.7
# 40                                   100                            18.3
# 24                                   100                            18.6
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 28                          16.6                       17.8
# 40                          17.3                       18.2
# 24                          18.2                       18.1
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 28                          18.0                          17.9
# 40                          18.6                          18.5
# 24                          18.9                          18.6

# %%
# Sort to find highest mean total/composite scores for ACT 2018

final.sort_values('Average Composite Score_ACT_18',ascending=False).head(4)
# Connecticut has the highest mean composite for ACT 2018 at 25.6
# Massachusetts and New Hampshire following closely behind at also around 25
# Out:
#             State  Participation_SAT_17  \
# 6     Connecticut                 100.0
# 21  Massachusetts                  76.0
# 29  New Hampshire                  96.0
# 32       New York                  67.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 6                                         530          512          1041
# 21                                        555          551          1107
# 29                                        532          520          1052
# 32                                        528          523          1052
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 6                   31.0            25.5         24.6            25.6
# 21                  29.0            25.4         25.3            25.9
# 29                  18.0            25.4         25.1            26.0
# 32                  31.0            23.8         24.0            24.6
#
#     Science_ACT_17  Composite_ACT_17  Participation_SAT_18  \
# 6             24.6              25.2                 100.0
# 21            24.7              25.4                  80.0
# 29            24.9              25.5                  96.0
# 32            23.9              24.2                  79.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 6                                         535          519          1053
# 21                                        562          563          1125
# 29                                        535          528          1063
# 32                                        534          534          1068
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 6                                     26                            25.6
# 21                                    25                            25.5
# 29                                    16                            25.1
# 32                                    27                            24.5
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 6                           26.0                       24.8
# 21                          25.5                       25.2
# 29                          25.1                       24.7
# 32                          24.2                       24.2
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 6                           26.1                          24.9
# 21                          25.9                          24.7
# 29                          25.6                          24.4
# 32                          24.9                          24.2

# %%
### Do any states with 100% participation on a given test have a rate change year-to-year?

# District of Columbia, Michigan, Connecticut and Delaware highest particpation rate for SAT 2017 at 100%
sat_17_100 = ['District of Columbia', 'Michigan', 'Connecticut', 'Delaware' ]

# Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, North Carolina, Nevada, Montana, Mississippi, Minnesota, Louisiana, Missouri, Wyoming, Colorado and Arkansas highest particpation rate for ACT 2017 at 100%
act_17_100 = ['Alabama', 'Kentucky', 'Wisconsin', 'Utah', 'Tennessee', 'South Carolina', 'Oklahoma', 'North Carolina', 'Nevada', 'Montana', 'Mississippi', 'Minnesota', 'Louisiana', 'Missouri', 'Wyoming', 'Colorado','Arkansas']

# %%
# States with 100% participation on SAT 2017
sat_17_100_df = final.loc[final['State'].isin(sat_17_100),['State','Participation_SAT_17','Total_SAT_17','Total_SAT_18']]
sat_17_100_df
# Out:
#                    State  Participation_SAT_17  Total_SAT_17  Total_SAT_18
# 6            Connecticut                 100.0          1041          1053
# 7               Delaware                 100.0           996           998
# 8   District of Columbia                 100.0           950           977
# 22              Michigan                 100.0          1005          1011

# %%
# Percentage change of SAT from year 2017 to 2018 for States with 100% participation
per_change_sat=pd.DataFrame(((sat_17_100_df['Total_SAT_18']-sat_17_100_df['Total_SAT_17']) / sat_17_100_df['Total_SAT_17'] )*100, columns =['Percent Change'])
pd.concat([sat_17_100_df,per_change_sat],axis=1)

# all below 3% improvement in SAT score from year 2017 to 2018
# Out:
#                    State  Participation_SAT_17  Total_SAT_17  Total_SAT_18  \
# 6            Connecticut                 100.0          1041          1053
# 7               Delaware                 100.0           996           998
# 8   District of Columbia                 100.0           950           977
# 22              Michigan                 100.0          1005          1011
#
#     Percent Change
# 6         1.152738
# 7         0.200803
# 8         2.842105
# 22        0.597015

# %%
# States with 100% participation on ACT 2017
act_17_100_df = final.loc[final['State'].isin(act_17_100),['State','Participation_ACT_17','Composite_ACT_17','Average Composite Score_ACT_18']]
act_17_100_df
# Out:
#              State  Participation_ACT_17  Composite_ACT_17  \
# 0          Alabama                 100.0              19.2
# 3         Arkansas                 100.0              19.4
# 5         Colorado                 100.0              20.8
# 17        Kentucky                 100.0              20.0
# 18       Louisiana                 100.0              19.5
# 23       Minnesota                 100.0              21.5
# 24     Mississippi                 100.0              18.6
# 25        Missouri                 100.0              20.4
# 26         Montana                 100.0              20.3
# 28          Nevada                 100.0              17.8
# 33  North Carolina                 100.0              19.1
# 36        Oklahoma                 100.0              19.4
# 40  South Carolina                 100.0              18.7
# 42       Tennessee                 100.0              19.8
# 44            Utah                 100.0              20.3
# 49       Wisconsin                 100.0              20.5
# 50         Wyoming                 100.0              20.2
#
#     Average Composite Score_ACT_18
# 0                             19.1
# 3                             19.4
# 5                             23.9
# 17                            20.2
# 18                            19.2
# 23                            21.3
# 24                            18.6
# 25                            20.0
# 26                            20.0
# 28                            17.7
# 33                            19.1
# 36                            19.3
# 40                            18.3
# 42                            19.6
# 44                            20.4
# 49                            20.5
# 50                            20.0

# %%
# Percentage change of ACT from year 2017 to 2018 for States with 100% participation
per_change_act=pd.DataFrame(((act_17_100_df['Average Composite Score_ACT_18']-act_17_100_df['Composite_ACT_17']) / act_17_100_df['Composite_ACT_17'] )*100, columns =['Percent Change'])
pd.concat([act_17_100_df,per_change_act],axis=1)

# Colorado seems to have good 14.9% improvement in ACT score from 20.8 to 23.9.
# Other states not much changes from year 2017 to 2018.
# Out:
#              State  Participation_ACT_17  Composite_ACT_17  \
# 0          Alabama                 100.0              19.2
# 3         Arkansas                 100.0              19.4
# 5         Colorado                 100.0              20.8
# 17        Kentucky                 100.0              20.0
# 18       Louisiana                 100.0              19.5
# 23       Minnesota                 100.0              21.5
# 24     Mississippi                 100.0              18.6
# 25        Missouri                 100.0              20.4
# 26         Montana                 100.0              20.3
# 28          Nevada                 100.0              17.8
# 33  North Carolina                 100.0              19.1
# 36        Oklahoma                 100.0              19.4
# 40  South Carolina                 100.0              18.7
# 42       Tennessee                 100.0              19.8
# 44            Utah                 100.0              20.3
# 49       Wisconsin                 100.0              20.5
# 50         Wyoming                 100.0              20.2
#
#     Average Composite Score_ACT_18  Percent Change
# 0                             19.1       -0.520833
# 3                             19.4        0.000000
# 5                             23.9       14.903846
# 17                            20.2        1.000000
# 18                            19.2       -1.538462
# 23                            21.3       -0.930233
# 24                            18.6        0.000000
# 25                            20.0       -1.960784
# 26                            20.0       -1.477833
# 28                            17.7       -0.561798
# 33                            19.1        0.000000
# 36                            19.3       -0.515464
# 40                            18.3       -2.139037
# 42                            19.6       -1.010101
# 44                            20.4        0.492611
# 49                            20.5        0.000000
# 50                            20.0       -0.990099

# %%
### Do any states show have >50% participation on both tests either year?

# States with >50% participation on both tests in year 2017:
final[(final['Participation_ACT_17']>50) & (final['Participation_SAT_17']>50)]
# Out:
#       State  Participation_SAT_17  Evidence-Based Reading and Writing_SAT_17  \
# 9   Florida                  83.0                                        520
# 10  Georgia                  61.0                                        535
# 11   Hawaii                  55.0                                        544
#
#     Math_SAT_17  Total_SAT_17  Participation_ACT_17  English_ACT_17  \
# 9           497          1017                  73.0            19.0
# 10          515          1050                  55.0            21.0
# 11          541          1085                  90.0            17.8
#
#     Math_ACT_17  Reading_ACT_17  Science_ACT_17  Composite_ACT_17  \
# 9          19.4            21.0            19.4              19.8
# 10         20.9            22.0            21.3              21.4
# 11         19.2            19.2            19.3              19.0
#
#     Participation_SAT_18  Evidence-Based Reading and Writing_SAT_18  \
# 9                   56.0                                        550
# 10                  70.0                                        542
# 11                  56.0                                        480
#
#     Math_SAT_18  Total_SAT_18  Percentage of Students Tested_ACT_18  \
# 9           549          1099                                    66
# 10          522          1064                                    53
# 11          530          1010                                    89
#
#     Average Composite Score_ACT_18  Average English Score_ACT_18  \
# 9                             19.9                          19.2
# 10                            21.4                          20.9
# 11                            18.9                          18.2
#
#     Average Math Score_ACT_18  Average Reading Score_ACT_18  \
# 9                        19.3                          21.1
# 10                       20.7                          21.2
# 11                       19.0                          19.1
#
#     Average Science Score_ACT_18
# 9                           19.5
# 10                          21.4
# 11                          19.0

# %%
# States with >50% participation on both tests in year 2018:
final[(final['Percentage of Students Tested_ACT_18']>50) & (final['Participation_SAT_18']>50)]
# Out:
#              State  Participation_SAT_17  \
# 9          Florida                  83.0
# 10         Georgia                  61.0
# 11          Hawaii                  55.0
# 33  North Carolina                  49.0
# 40  South Carolina                  50.0
#
#     Evidence-Based Reading and Writing_SAT_17  Math_SAT_17  Total_SAT_17  \
# 9                                         520          497          1017
# 10                                        535          515          1050
# 11                                        544          541          1085
# 33                                        546          535          1081
# 40                                        543          521          1064
#
#     Participation_ACT_17  English_ACT_17  Math_ACT_17  Reading_ACT_17  \
# 9                   73.0            19.0         19.4            21.0
# 10                  55.0            21.0         20.9            22.0
# 11                  90.0            17.8         19.2            19.2
# 33                 100.0            17.8         19.3            19.6
# 40                 100.0            17.5         18.6            19.1
#
#     Science_ACT_17  Composite_ACT_17  Participation_SAT_18  \
# 9             19.4              19.8                  56.0
# 10            21.3              21.4                  70.0
# 11            19.3              19.0                  56.0
# 33            19.3              19.1                  52.0
# 40            18.9              18.7                  55.0
#
#     Evidence-Based Reading and Writing_SAT_18  Math_SAT_18  Total_SAT_18  \
# 9                                         550          549          1099
# 10                                        542          522          1064
# 11                                        480          530          1010
# 33                                        554          543          1098
# 40                                        547          523          1070
#
#     Percentage of Students Tested_ACT_18  Average Composite Score_ACT_18  \
# 9                                     66                            19.9
# 10                                    53                            21.4
# 11                                    89                            18.9
# 33                                   100                            19.1
# 40                                   100                            18.3
#
#     Average English Score_ACT_18  Average Math Score_ACT_18  \
# 9                           19.2                       19.3
# 10                          20.9                       20.7
# 11                          18.2                       19.0
# 33                          18.0                       19.3
# 40                          17.3                       18.2
#
#     Average Reading Score_ACT_18  Average Science Score_ACT_18
# 9                           21.1                          19.5
# 10                          21.2                          21.4
# 11                          19.1                          19.0
# 33                          19.5                          19.2
# 40                          18.6                          18.5

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
# Establish size of figure.
plt.figure(figsize=(12,10))

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(final.corr())
mask[np.triu_indices_from(mask)] = True

sns.heatmap(final.corr(), mask=mask,annot=True).set(title="Correlation between all the numerical variables");

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        # Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Code

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Establish the size of the figure.
plt.figure(figsize=(16, 9))
# Create Scatterplot for SAT vs. ACT math scores for different states and DC in 2017
plt.scatter(final['Math_SAT_17'],final['Math_ACT_17']);
plt.title("SAT vs. ACT math scores for different states and DC in 2017", fontsize = 20)
plt.xlabel("Math score for SAT 2017", fontsize = 20)
plt.ylabel("Math score for ACT 2017", fontsize = 20)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);

# There is a quadratic curvature correlation. 
# States/DC that do better for Math SAT 2017 tends to do worse for Math ACT 2017, vice versa.

# %%
# Establish the size of the figure.
plt.figure(figsize=(16, 9))
# Create Scatterplot for SAT vs. ACT verbal/reading scores for different states and DC in 2017
plt.scatter(final['Evidence-Based Reading and Writing_SAT_17'],final['Reading_ACT_17']);
plt.title("SAT vs. ACT verbal/reading scores for different states and DC in 2017", fontsize = 20)
plt.xlabel("Evidence-Based Reading and Writing score for SAT 2017", fontsize = 20)
plt.ylabel("Reading score for ACT 2017", fontsize = 20)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);

# There is a quadratic curvature correlation. 
# States/DC that do better for reading and writing SAT 2017 tends to do worse for reading ACT 2017, vice versa.

# %%
# Establish the size of the figure.
plt.figure(figsize=(16, 9))
# Create Scatterplot for SAT vs. ACT total/composite scores for different states and DC in 2017
plt.scatter(final['Total_SAT_17'],final['Composite_ACT_17']);
plt.title("SAT vs. ACT total/composite scores for different states and DC in 2017", fontsize = 20)
plt.xlabel("Total score for SAT 2017", fontsize = 20)
plt.ylabel("Composite score for ACT 2017", fontsize = 20)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);

# There is a quadratic curvature correlation. 
# States/DC that do better for total SAT 2017 tends to do worse for composite ACT 2017, vice versa.

# %%
# Establish the size of the figure.
plt.figure(figsize=(16, 9))
# Create Scatterplot for SAT total scores for different states and DC in 2017 vs 2018
plt.scatter(final['Total_SAT_17'],final['Total_SAT_18']);
plt.title("SAT total scores for different states and DC in 2017 vs 2018", fontsize = 20)
plt.xlabel("Total score for SAT 2017", fontsize = 20)
plt.ylabel("Total score for SAT 2018", fontsize = 20)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);

# There is a linear correlation. States/DC that do better in 2017 tend to do better in 2018 as well, vice versa.
# There is are 2 states/DC which deviates from the correlation, 
# both of which seems to get poorer of score from around 1200 to 1000 for year 2017 to 2018

# %%
# Establish the size of the figure.
plt.figure(figsize=(16, 9))
# Create Scatterplot for ACT Composite scores for different states and DC in 2017 vs 2018
plt.scatter(final['Composite_ACT_17'],final['Average Composite Score_ACT_18']);
plt.title("ACT Composite scores for different states and DC in 2017 vs 2018", fontsize = 20)
plt.xlabel("Composite score for ACT 2017", fontsize = 20)
plt.ylabel("Composite score for ACT 2018", fontsize = 20)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);

# There is a linear correlation. States/DC that do better in 2017 tend to do better in 2018 as well, vice versa.
# There is are 2 states/DC which deviates from the correlation, 
# both of which seems to make significant improvement of score from around 21 to 24 for year 2017 to 2018

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
final.boxplot()

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:

# %% [markdown]
# #### Distributions in the data
#
# In this dataset, each data represents a sample from a population.
# For example, for ACT math test:
# - Population: the test results of all the students who take this test, nation-wide.
# - Population mean: is the national average of ACT math test (total scores/total no. of test takers)
# - Sample: the state means of ACT math test. We have 51 samples (51 states)
#
# ***According to CLT, we generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?***

# %% [markdown]
# Answer:

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores  - can we say students with higher SAT math score is better than those with lower ACT math score, or vice versa?
#
# Why or why not?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?
