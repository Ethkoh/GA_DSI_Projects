# %% [markdown]
# ### Understanding Pycaret
#
# https://towardsdatascience.com/announcing-pycaret-an-open-source-low-code-machine-learning-library-in-python-4a1f1aad8d46
#
# https://www.youtube.com/watch?time_continue=1&v=scd6KS03NiE&feature=emb_logo

# %%
#!pip install pycaret

# %%
#!pip install lightgbm

# %%
import pandas as pd

# %%
data=pd.read_csv("X.csv")
data2=pd.read_csv("y.csv")
data['target']=data2

# %%
from pycaret.classification import *
from pycaret import preprocess
exp1 = setup(data, target = 'target')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_7def32ce_a24e_11ea_8d78_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7def32ce_a24e_11ea_8d78_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7def32ce_a24e_11ea_8d78_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_7def32ce_a24e_11ea_8d78_acde48001122row0_col1" class="data row0 col1" >7866</td>
#             </tr>
#             <tr>
#                         <th id="T_7def32ce_a24e_11ea_8d78_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7def32ce_a24e_11ea_8d78_acde48001122row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_a9734fde_a24e_11ea_8d78_acde48001122 th {
#           text-align: left;
#     }    #T_a9734fde_a24e_11ea_8d78_acde48001122row0_col0 {
#             text-align:  left;
#         }    #T_a9734fde_a24e_11ea_8d78_acde48001122row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_a9734fde_a24e_11ea_8d78_acde48001122row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_a9734fde_a24e_11ea_8d78_acde48001122row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_a9734fde_a24e_11ea_8d78_acde48001122row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_a9734fde_a24e_11ea_8d78_acde48001122row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_a9734fde_a24e_11ea_8d78_acde48001122row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_a9734fde_a24e_11ea_8d78_acde48001122row1_col0 {
# ...

# %%
gbc= create_model('gbc')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9470  0.8590  0.0000  0.0000  0.0000  0.0000
# 1       0.9484  0.8072  0.0256  1.0000  0.0500  0.0475
# 2       0.9457  0.8025  0.0000  0.0000  0.0000 -0.0027
# 3       0.9497  0.8636  0.0513  1.0000  0.0976  0.0929
# 4       0.9483  0.7957  0.0263  0.5000  0.0500  0.0451
# 5       0.9469  0.9004  0.0000  0.0000  0.0000 -0.0027
# 6       0.9469  0.8373  0.0000  0.0000  0.0000 -0.0027
# 7       0.9483  0.8442  0.0000  0.0000  0.0000  0.0000
# 8       0.9483  0.8427  0.0513  0.6667  0.0952  0.0883
# 9       0.9483  0.8314  0.0513  0.6667  0.0952  0.0883
# Mean    0.9478  0.8384  0.0206  0.3833  0.0388  0.0354
# SD      0.0011  0.0301  0.0224  0.4086  0.0420  0.0400

# %%
tuned_boost = tune_model('gbc')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9443  0.8464  0.0000  0.0000  0.0000 -0.0052
# 1       0.9470  0.8012  0.0513  0.5000  0.0930  0.0840
# 2       0.9457  0.8126  0.0000  0.0000  0.0000 -0.0027
# 3       0.9457  0.8266  0.0513  0.4000  0.0909  0.0798
# 4       0.9483  0.7953  0.0263  0.5000  0.0500  0.0451
# 5       0.9442  0.8705  0.0000  0.0000  0.0000 -0.0076
# 6       0.9442  0.8005  0.0263  0.2000  0.0465  0.0349
# 7       0.9442  0.7944  0.0526  0.2857  0.0889  0.0740
# 8       0.9483  0.8248  0.0513  0.6667  0.0952  0.0883
# 9       0.9483  0.8149  0.0256  1.0000  0.0500  0.0475
# Mean    0.9460  0.8187  0.0285  0.3552  0.0515  0.0438
# SD      0.0017  0.0232  0.0214  0.3105  0.0382  0.0362

# %%
# creating a decision tree model
dt = create_model('dt')
# ensembling a trained dt model
dt_bagged = ensemble_model(dt)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9375  0.8043  0.0513  0.1818  0.0800  0.0580
# 1       0.9429  0.7646  0.0769  0.3333  0.1250  0.1073
# 2       0.9443  0.7223  0.0513  0.3333  0.0889  0.0758
# 3       0.9443  0.7438  0.1026  0.4000  0.1633  0.1448
# 4       0.9456  0.7656  0.0263  0.2500  0.0476  0.0381
# 5       0.9361  0.8059  0.0000  0.0000  0.0000 -0.0202
# 6       0.9456  0.7376  0.0789  0.3750  0.1304  0.1145
# 7       0.9415  0.7292  0.1316  0.3333  0.1887  0.1642
# 8       0.9456  0.7990  0.0513  0.4000  0.0909  0.0798
# 9       0.9415  0.7429  0.1026  0.3333  0.1569  0.1353
# Mean    0.9425  0.7615  0.0673  0.2940  0.1072  0.0898
# SD      0.0032  0.0301  0.0372  0.1167  0.0543  0.0525

# %%
# create a model
gbc = create_model('gbc')
# AUC plot
plot_model(gbc, plot = 'auc')
# Decision Boundary
plot_model(gbc, plot = 'boundary')
# Precision Recall Curve
plot_model(gbc, plot = 'pr')
# Validation Curve
plot_model(gbc, plot = 'vc')

# %%
evaluate_model(adaboost)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
# create a model
xgboost = create_model('xgboost')
# summary plot
interpret_model(xgboost)
# correlation plot
interpret_model(xgboost, plot = 'correlation')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7407  0.8782  0.4737  0.6923  0.5625  0.3874
# 1       0.7222  0.8165  0.5263  0.6250  0.5714  0.3682
# 2       0.7963  0.8135  0.7368  0.7000  0.7179  0.5587
# 3       0.7593  0.8586  0.5789  0.6875  0.6286  0.4524
# 4       0.7407  0.7429  0.5789  0.6471  0.6111  0.4176
# 5       0.7407  0.7474  0.5789  0.6471  0.6111  0.4176
# 6       0.6852  0.7654  0.5263  0.5556  0.5405  0.3014
# 7       0.7925  0.8175  0.5000  0.8182  0.6207  0.4890
# 8       0.8868  0.9524  0.7222  0.9286  0.8125  0.7332
# 9       0.7736  0.8698  0.7222  0.6500  0.6842  0.5085
# Mean    0.7638  0.8262  0.5944  0.6951  0.6361  0.4634
# SD      0.0516  0.0623  0.0930  0.1004  0.0777  0.1140

# %%
interpret_model(xgboost, plot = 'reason', observation = 0)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
# create a model
rf = create_model('rf')
# predict test / hold-out dataset
rf_holdout_pred = predict_model(rf)
# Out:
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0  Random Forest Classifier    0.7403  0.7588  0.5062  0.6721  0.5775  0.3953

# %%
predictions = predict_model(rf, data = diabetes)

# %%
deploy_model(model = rf, model_name = 'rf_aws', platform = 'aws', 
             authentication =  {'bucket'  : 'pycaret-test'})
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# <ipython-input-15-9924d2a8952e> in <module>
#       1 deploy_model(model = rf, model_name = 'rf_aws', platform = 'aws',
# ----> 2              authentication =  {'bucket'  : 'pycaret-test'})
#
# /opt/anaconda3/lib/python3.7/site-packages/pycaret/classification.py in deploy_model(model, model_name, authentication, platform)
#    8142         key = str(model_name)+'.pkl'
#    8143         bucket_name = authentication.get('bucket')
# -> 8144         s3.upload_file(filename,bucket_name,key)
#    8145         clear_output()
#    8146         print("Model Succesfully Deployed on AWS S3")
#
# /opt/anaconda3/lib/python3.7/site-packages/boto3/s3/inject.py in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     129         return transfer.upload_file(
#     130             filename=Filename, bucket=Bucket, key=Key,
# ...
