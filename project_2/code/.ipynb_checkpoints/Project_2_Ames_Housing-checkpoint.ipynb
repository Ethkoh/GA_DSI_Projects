# %% [markdown]
# # Project 2: Predict Sale Price of Houses in Ames, Iowa
#    ---
#   *By Ethan Koh, 28 April 2020*

# %% [markdown]
# ## Overview and Problem Set

# %% [markdown]
# The property market is not for the ill-informed. Housing prices can be cruelly volatile as they can get affected by multiple factors. Every buyer and seller of a house seek to equip with better knowledge to achieve a reasonable transaction price. Even though it's not possible for every contributing factor to be captured by our dataset, given the housing dataset in Ames Iowa, we are going to create a regression model that predicts the price of houses in Ames. In addition, we will be able to discover what are the main factors contributing to the price.

# %% [markdown]
# ## Datasets

# %% [markdown]
# These datasets are provided by General Assembly for our course Kaggle competition. The dataset was prepared by Dean De Cock taken from the Ames, Iowa Assessor’s Office, originally used for tax assessment purpose. Data set contains information used in computing assessed values for individual residential properties sold in Ames, Iowa from 2006 to 2010.
#
# The data by Dean De Cook has 82 columns which include 23 nominal, 23 ordinal, 14 discrete, and 20 continuous variables, and 2 additional observation identifiers. However, data given by General Assembly has 81 columns, with 'Sale Condition' variable excluded, which include 22 nominal, 23 ordinal, 14 discrete, and 20 continuous variables, and 2 additional observation identifiers.
#
# - train.csv <br />
# - test.csv <br />

# %% [markdown]
# ## Data Dictionary
#
# [LINK](http://jse.amstat.org/v19n3/decock/DataDocumentation.txt)

# %% [markdown]
# ## Assumptions and Limitations
# Using multi-linear regression has it's own assumptions:<br />
# Firstly, the predictors and target variable have an approximate linear relationship.<br />
# Secondly, residuals are independent of each other, follows a Normal distribution with mean 0 and have roughly equal variances.<br />
# Thirdly, the predictors are independent of each other.<br />
#
# In addition, there are limitations to predict future prices based on a 2006-2010 old dataset that we have. Many of the predictors for sale price may no longer be significant.

# %% [markdown]
# ## Table of Contents
# - Import Libraries<br />
# - Load and read Training dataset<br />
# - Data cleaning <br />
# - Exploratory Data Analysis<br />
#
#
# Handling missing values
# Garage from the future...?
# Exploratory Data Analysis
# The target - SalePrice
# Handling Extreme Sale Prices
# Preliminary Feature Correlations
# Feature Engineering
# House Age
# House Total Area
# House Total Baths
# createInteraction Helper Function
# Establishing conversion dictionaries
# Simple conversions
# Quality * Condition = Score
# Quality + Area/Count = Score
# createDummies Helper Function
# Creating dummy variables
# Final Feature Correlations
# Model Preparation
# Establishing baseline model
# Fitting Model
# Model Evaluation
# getBestModel Helper Function
# Plotting Predicted Sale Price vs. Actual Sale Price
# Plotting Residuals
# Inferrential Statistics and Conclusions
# Model Coefficients
# Model Assumptions
# Kaggle Submission
# Sources

# %% [markdown]
# ## Import Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, KFold, cross_val_score

# %matplotlib inline

# %% [markdown]
# ## Load and read Training dataset

# %%
# There are 12 features(columns) with NA as a value with meaning
# Hence during import set defaul na as False
housing = pd.read_csv("../datasets/train.csv",index_col="Id",keep_default_na=False)

# %% [markdown]
# ## Data cleaning

# %%
#set option to view all columns
pd.set_option('display.max_columns', 100)
housing.head()
# Out:
#            PID  MS SubClass MS Zoning Lot Frontage  Lot Area Street Alley  \
# Id
# 109  533352170           60        RL                  13517   Pave    NA
# 544  531379050           60        RL           43     11492   Pave    NA
# 153  535304180           20        RL           68      7922   Pave    NA
# 318  916386060           60        RL           73      9802   Pave    NA
# 255  906425045           50        RL           82     14235   Pave    NA
#
#     Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# Id
# 109       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 544       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 153       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 318       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 255       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#     Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# Id
# 109        RRAe        Norm      1Fam      2Story             6             8
# 544        Norm        Norm      1Fam      2Story             7             5
# 153        Norm        Norm      1Fam      1Story             5             7
# 318        Norm        Norm      1Fam      2Story             5             5
# 255        Norm        Norm      1Fam      1.5Fin             6             8
#
#      Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# Id
# 109        1976            2005      Gable   CompShg      HdBoard
# 544        1996            1997      Gable   CompShg      VinylSd
# 153        1953            2007      Gable   CompShg      VinylSd
# 318        2006            2007      Gable   CompShg      VinylSd
# 255        1900            1993      Gable   CompShg      Wd Sdng
#
#     Exterior 2nd Mas Vnr Type Mas Vnr Area Exter Qual Exter Cond Foundation  \
# Id
# 109      Plywood      BrkFace          289         Gd         TA     CBlock
# 544      VinylSd      BrkFace          132         Gd         TA      PConc
# 153      VinylSd         None            0         TA         Gd     CBlock
# 318      VinylSd         None            0         TA         TA      PConc
# 255      Plywood         None            0         TA         TA      PConc
#
#     Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1 BsmtFin SF 1  \
# Id
# 109        TA        TA            No            GLQ          533
# 544        Gd        TA            No            GLQ          637
# 153        TA        TA            No            GLQ          731
# 318        Gd        TA            No            Unf            0
# 255        Fa        Gd            No            Unf            0
#
#     BsmtFin Type 2 BsmtFin SF 2 Bsmt Unf SF Total Bsmt SF Heating Heating QC  \
# Id
# 109            Unf            0         192           725    GasA         Ex
# 544            Unf            0         276           913    GasA         Ex
# 153            Unf            0         326          1057    GasA         TA
# 318            Unf            0         384           384    GasA         Gd
# 255            Unf            0         676           676    GasA         TA
#
#     Central Air Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  \
# Id
# 109           Y      SBrkr         725         754                0
# 544           Y      SBrkr         913        1209                0
# 153           Y      SBrkr        1057           0                0
# 318           Y      SBrkr         744         700                0
# 255           Y      SBrkr         831         614                0
#
#      Gr Liv Area Bsmt Full Bath Bsmt Half Bath  Full Bath  Half Bath  \
# Id
# 109         1479              0              0          2          1
# 544         2122              1              0          2          1
# 153         1057              1              0          1          0
# 318         1444              0              0          2          1
# 255         1445              0              0          2          0
#
#      Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  \
# Id
# 109              3              1           Gd              6        Typ
# 544              4              1           Gd              8        Typ
# 153              3              1           Gd              5        Typ
# 318              3              1           TA              7        Typ
# 255              3              1           TA              6        Typ
#
#      Fireplaces Fireplace Qu Garage Type Garage Yr Blt Garage Finish  \
# Id
# 109           0           NA      Attchd          1976           RFn
# 544           1           TA      Attchd          1997           RFn
# 153           0           NA      Detchd          1953           Unf
# 318           0           NA     BuiltIn          2007           Fin
# 255           0           NA      Detchd          1957           Unf
#
#     Garage Cars Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# Id
# 109           2         475          TA          TA           Y             0
# 544           2         559          TA          TA           Y             0
# 153           1         246          TA          TA           Y             0
# 318           2         400          TA          TA           Y           100
# 255           2         484          TA          TA           N             0
#
#      Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area  \
# Id
# 109             44               0           0             0          0
# 544             74               0           0             0          0
# 153             52               0           0             0          0
# 318              0               0           0             0          0
# 255             59               0           0             0          0
#
#     Pool QC Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  \
# Id
# 109      NA    NA           NA         0        3     2010       WD
# 544      NA    NA           NA         0        4     2009       WD
# 153      NA    NA           NA         0        1     2010       WD
# 318      NA    NA           NA         0        4     2010       WD
# 255      NA    NA           NA         0        3     2010       WD
#
#      SalePrice
# Id
# 109     130500
# 544     220000
# 153     109000
# 318     174000
# 255     138500

# %%
# check data shape
housing.shape
# Out:
# (2051, 80)

# %%
# replace real missing data with NaN
housing.replace('', np.nan,inplace=True)

# %%
# check for nulls
housing.isnull().sum()[housing.isnull().sum()>0]
# Out:
# Lot Frontage      330
# Mas Vnr Type       22
# Mas Vnr Area       22
# Bsmt Qual           1
# Bsmt Cond           1
# Bsmt Exposure       4
# BsmtFin Type 1      1
# BsmtFin SF 1        1
# BsmtFin Type 2      2
# BsmtFin SF 2        1
# Bsmt Unf SF         1
# Total Bsmt SF       1
# Bsmt Full Bath      2
# Bsmt Half Bath      2
# Garage Yr Blt     114
# Garage Finish       1
# Garage Cars         1
# Garage Area         1
# Garage Qual         1
# Garage Cond         1
# dtype: int64

# %%
# drop one of the identifier variable. no need to have 2 index
housing.drop('PID',axis=1,inplace=True)
housing.shape
# Out:
# (2051, 79)

# %%
# random check whether it is the same null value in some of the predictors
housing[housing['BsmtFin SF 1'].isnull()]
# Out:
#       MS SubClass MS Zoning Lot Frontage  Lot Area Street Alley Lot Shape  \
# Id
# 1342           20        RM           99      5940   Pave    NA       IR1
#
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# Id
# 1342          Lvl    AllPub        FR3        Gtl      BrkSide       Feedr
#
#      Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# Id
# 1342        Norm      1Fam      1Story             4             7
#
#       Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# Id
# 1342        1946            1950      Gable   CompShg      MetalSd
#
#      Exterior 2nd Mas Vnr Type Mas Vnr Area Exter Qual Exter Cond Foundation  \
# Id
# 1342       CBlock         None            0         TA         TA      PConc
#
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1 BsmtFin SF 1  \
# Id
# 1342       NaN       NaN           NaN            NaN          NaN
#
#      BsmtFin Type 2 BsmtFin SF 2 Bsmt Unf SF Total Bsmt SF Heating Heating QC  \
# Id
# 1342            NaN          NaN         NaN           NaN    GasA         TA
#
#      Central Air Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  \
# Id
# 1342           Y      FuseA         896           0                0
#
#       Gr Liv Area Bsmt Full Bath Bsmt Half Bath  Full Bath  Half Bath  \
# Id
# 1342          896            NaN            NaN          1          0
#
#       Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  \
# Id
# 1342              2              1           TA              4        Typ
#
#       Fireplaces Fireplace Qu Garage Type Garage Yr Blt Garage Finish  \
# Id
# 1342           0           NA      Detchd          1946           Unf
#
#      Garage Cars Garage Area Garage Qual Garage Cond Paved Drive  \
# Id
# 1342           1         280          TA          TA           Y
#
#       Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# Id
# 1342             0              0               0           0             0
#
#       Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  Yr Sold  \
# Id
# 1342          0      NA  MnPrv           NA         0        4     2008
#
#      Sale Type  SalePrice
# Id
# 1342     ConLD      79000

# %%
housing[housing['Total Bsmt SF'].isnull()]
# it is the same ID having many nulls. id=1342. probably is completely missing at random.
# Out:
#       MS SubClass MS Zoning Lot Frontage  Lot Area Street Alley Lot Shape  \
# Id
# 1342           20        RM           99      5940   Pave    NA       IR1
#
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# Id
# 1342          Lvl    AllPub        FR3        Gtl      BrkSide       Feedr
#
#      Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# Id
# 1342        Norm      1Fam      1Story             4             7
#
#       Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# Id
# 1342        1946            1950      Gable   CompShg      MetalSd
#
#      Exterior 2nd Mas Vnr Type Mas Vnr Area Exter Qual Exter Cond Foundation  \
# Id
# 1342       CBlock         None            0         TA         TA      PConc
#
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1 BsmtFin SF 1  \
# Id
# 1342       NaN       NaN           NaN            NaN          NaN
#
#      BsmtFin Type 2 BsmtFin SF 2 Bsmt Unf SF Total Bsmt SF Heating Heating QC  \
# Id
# 1342            NaN          NaN         NaN           NaN    GasA         TA
#
#      Central Air Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  \
# Id
# 1342           Y      FuseA         896           0                0
#
#       Gr Liv Area Bsmt Full Bath Bsmt Half Bath  Full Bath  Half Bath  \
# Id
# 1342          896            NaN            NaN          1          0
#
#       Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  \
# Id
# 1342              2              1           TA              4        Typ
#
#       Fireplaces Fireplace Qu Garage Type Garage Yr Blt Garage Finish  \
# Id
# 1342           0           NA      Detchd          1946           Unf
#
#      Garage Cars Garage Area Garage Qual Garage Cond Paved Drive  \
# Id
# 1342           1         280          TA          TA           Y
#
#       Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# Id
# 1342             0              0               0           0             0
#
#       Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  Yr Sold  \
# Id
# 1342          0      NA  MnPrv           NA         0        4     2008
#
#      Sale Type  SalePrice
# Id
# 1342     ConLD      79000

# %%
# remove id=1342
housing.drop(1342,inplace=True)

# %%
# check for nulls again
housing.isnull().sum()[housing.isnull().sum()>0]
# Out:
# Lot Frontage      330
# Mas Vnr Type       22
# Mas Vnr Area       22
# Bsmt Exposure       3
# BsmtFin Type 2      1
# Bsmt Full Bath      1
# Bsmt Half Bath      1
# Garage Yr Blt     114
# Garage Finish       1
# Garage Cars         1
# Garage Area         1
# Garage Qual         1
# Garage Cond         1
# dtype: int64

# %%
# random check whether it is the same null value in some of the predictors
housing[housing['Garage Cond'].isnull()]
# Out:
#       MS SubClass MS Zoning Lot Frontage  Lot Area Street Alley Lot Shape  \
# Id
# 2237           70        RM           50      9060   Pave    NA       Reg
#
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# Id
# 2237          Lvl    AllPub     Inside        Gtl       IDOTRR        Norm
#
#      Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# Id
# 2237        Norm      1Fam      2Story             5             6
#
#       Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# Id
# 2237        1923            1999      Gable   CompShg      Wd Sdng
#
#      Exterior 2nd Mas Vnr Type Mas Vnr Area Exter Qual Exter Cond Foundation  \
# Id
# 2237      Plywood         None            0         TA         TA     BrkTil
#
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1 BsmtFin SF 1  \
# Id
# 2237        Gd        TA            No            ALQ          548
#
#      BsmtFin Type 2 BsmtFin SF 2 Bsmt Unf SF Total Bsmt SF Heating Heating QC  \
# Id
# 2237            Unf            0         311           859    GasA         Ex
#
#      Central Air Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  \
# Id
# 2237           Y      SBrkr         942         886                0
#
#       Gr Liv Area Bsmt Full Bath Bsmt Half Bath  Full Bath  Half Bath  \
# Id
# 2237         1828              0              0          2          0
#
#       Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  \
# Id
# 2237              3              1           Gd              6        Typ
#
#       Fireplaces Fireplace Qu Garage Type Garage Yr Blt Garage Finish  \
# Id
# 2237           0           NA      Detchd           NaN           NaN
#
#      Garage Cars Garage Area Garage Qual Garage Cond Paved Drive  \
# Id
# 2237         NaN         NaN         NaN         NaN           Y
#
#       Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# Id
# 2237           174              0             212           0             0
#
#       Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  Yr Sold  \
# Id
# 2237          0      NA  MnPrv           NA         0        3     2007
#
#      Sale Type  SalePrice
# Id
# 2237       WD      150909

# %%
housing[housing['Garage Qual'].isnull()]
# it is the same ID having many nulls. id=2237. probably is completely missing at random.
# Out:
#       MS SubClass MS Zoning Lot Frontage  Lot Area Street Alley Lot Shape  \
# Id
# 2237           70        RM           50      9060   Pave    NA       Reg
#
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# Id
# 2237          Lvl    AllPub     Inside        Gtl       IDOTRR        Norm
#
#      Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# Id
# 2237        Norm      1Fam      2Story             5             6
#
#       Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# Id
# 2237        1923            1999      Gable   CompShg      Wd Sdng
#
#      Exterior 2nd Mas Vnr Type Mas Vnr Area Exter Qual Exter Cond Foundation  \
# Id
# 2237      Plywood         None            0         TA         TA     BrkTil
#
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1 BsmtFin SF 1  \
# Id
# 2237        Gd        TA            No            ALQ          548
#
#      BsmtFin Type 2 BsmtFin SF 2 Bsmt Unf SF Total Bsmt SF Heating Heating QC  \
# Id
# 2237            Unf            0         311           859    GasA         Ex
#
#      Central Air Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  \
# Id
# 2237           Y      SBrkr         942         886                0
#
#       Gr Liv Area Bsmt Full Bath Bsmt Half Bath  Full Bath  Half Bath  \
# Id
# 2237         1828              0              0          2          0
#
#       Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  \
# Id
# 2237              3              1           Gd              6        Typ
#
#       Fireplaces Fireplace Qu Garage Type Garage Yr Blt Garage Finish  \
# Id
# 2237           0           NA      Detchd           NaN           NaN
#
#      Garage Cars Garage Area Garage Qual Garage Cond Paved Drive  \
# Id
# 2237         NaN         NaN         NaN         NaN           Y
#
#       Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# Id
# 2237           174              0             212           0             0
#
#       Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  Yr Sold  \
# Id
# 2237          0      NA  MnPrv           NA         0        3     2007
#
#      Sale Type  SalePrice
# Id
# 2237       WD      150909

# %%
# remove id=2237
housing.drop(2237,inplace=True)

# %%
# check for nulls again
housing.isnull().sum()[housing.isnull().sum()>0]
# Out:
# Lot Frontage      330
# Mas Vnr Type       22
# Mas Vnr Area       22
# Bsmt Exposure       3
# BsmtFin Type 2      1
# Bsmt Full Bath      1
# Bsmt Half Bath      1
# Garage Yr Blt     113
# dtype: int64

# %%
# random check whether it is the same null value in some of the predictors
housing[housing['BsmtFin Type 2'].isnull()]
# Out:
#      MS SubClass MS Zoning Lot Frontage  Lot Area Street Alley Lot Shape  \
# Id
# 445           20        RL           85     10655   Pave    NA       IR1
#
#     Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# Id
# 445          Lvl    AllPub     Inside        Gtl      NridgHt        Norm
#
#     Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# Id
# 445        Norm      1Fam      1Story             8             5        2003
#
#      Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# Id
# 445            2004      Gable   CompShg      VinylSd      VinylSd
#
#     Mas Vnr Type Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# Id
# 445      BrkFace          296         Gd         TA      PConc        Gd
#
#     Bsmt Cond Bsmt Exposure BsmtFin Type 1 BsmtFin SF 1 BsmtFin Type 2  \
# Id
# 445        TA            No            GLQ         1124            NaN
#
#     BsmtFin SF 2 Bsmt Unf SF Total Bsmt SF Heating Heating QC Central Air  \
# Id
# 445          479        1603          3206    GasA         Ex           Y
#
#     Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# Id
# 445      SBrkr        1629           0                0         1629
#
#     Bsmt Full Bath Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# Id
# 445              1              0          2          0              3
#
#      Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# Id
# 445              1           Gd              7        Typ           1
#
#     Fireplace Qu Garage Type Garage Yr Blt Garage Finish Garage Cars  \
# Id
# 445           Gd      Attchd          2003           RFn           3
#
#     Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# Id
# 445         880          TA          TA           Y             0
#
#      Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area  \
# Id
# 445              0               0           0             0          0
#
#     Pool QC Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  \
# Id
# 445      NA    NA           NA         0       10     2009       WD
#
#      SalePrice
# Id
# 445     284000

# %%
housing[housing['Bsmt Half Bath'].isnull()]
# Out:
#       MS SubClass MS Zoning Lot Frontage  Lot Area Street Alley Lot Shape  \
# Id
# 1498           20        RL          123     47007   Pave    NA       IR1
#
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# Id
# 1498          Lvl    AllPub     Inside        Gtl      Edwards        Norm
#
#      Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# Id
# 1498        Norm      1Fam      1Story             5             7
#
#       Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# Id
# 1498        1959            1996      Gable   CompShg      Plywood
#
#      Exterior 2nd Mas Vnr Type Mas Vnr Area Exter Qual Exter Cond Foundation  \
# Id
# 1498      Plywood         None            0         TA         TA       Slab
#
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1 BsmtFin SF 1  \
# Id
# 1498        NA        NA            NA             NA            0
#
#      BsmtFin Type 2 BsmtFin SF 2 Bsmt Unf SF Total Bsmt SF Heating Heating QC  \
# Id
# 1498             NA            0           0             0    GasA         TA
#
#      Central Air Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  \
# Id
# 1498           Y      SBrkr        3820           0                0
#
#       Gr Liv Area Bsmt Full Bath Bsmt Half Bath  Full Bath  Half Bath  \
# Id
# 1498         3820            NaN            NaN          3          1
#
#       Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  \
# Id
# 1498              5              1           Ex             11        Typ
#
#       Fireplaces Fireplace Qu Garage Type Garage Yr Blt Garage Finish  \
# Id
# 1498           2           Gd      Attchd          1959           Unf
#
#      Garage Cars Garage Area Garage Qual Garage Cond Paved Drive  \
# Id
# 1498           2         624          TA          TA           Y
#
#       Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# Id
# 1498             0            372               0           0             0
#
#       Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  Yr Sold  \
# Id
# 1498          0      NA    NA           NA         0        7     2008
#
#      Sale Type  SalePrice
# Id
# 1498       WD      284700

# %%
housing[housing['Bsmt Half Bath'].isnull()]
# Out:
#       MS SubClass MS Zoning Lot Frontage  Lot Area Street Alley Lot Shape  \
# Id
# 1498           20        RL          123     47007   Pave    NA       IR1
#
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# Id
# 1498          Lvl    AllPub     Inside        Gtl      Edwards        Norm
#
#      Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# Id
# 1498        Norm      1Fam      1Story             5             7
#
#       Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# Id
# 1498        1959            1996      Gable   CompShg      Plywood
#
#      Exterior 2nd Mas Vnr Type Mas Vnr Area Exter Qual Exter Cond Foundation  \
# Id
# 1498      Plywood         None            0         TA         TA       Slab
#
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1 BsmtFin SF 1  \
# Id
# 1498        NA        NA            NA             NA            0
#
#      BsmtFin Type 2 BsmtFin SF 2 Bsmt Unf SF Total Bsmt SF Heating Heating QC  \
# Id
# 1498             NA            0           0             0    GasA         TA
#
#      Central Air Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  \
# Id
# 1498           Y      SBrkr        3820           0                0
#
#       Gr Liv Area Bsmt Full Bath Bsmt Half Bath  Full Bath  Half Bath  \
# Id
# 1498         3820            NaN            NaN          3          1
#
#       Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  \
# Id
# 1498              5              1           Ex             11        Typ
#
#       Fireplaces Fireplace Qu Garage Type Garage Yr Blt Garage Finish  \
# Id
# 1498           2           Gd      Attchd          1959           Unf
#
#      Garage Cars Garage Area Garage Qual Garage Cond Paved Drive  \
# Id
# 1498           2         624          TA          TA           Y
#
#       Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# Id
# 1498             0            372               0           0             0
#
#       Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  Yr Sold  \
# Id
# 1498          0      NA    NA           NA         0        7     2008
#
#      Sale Type  SalePrice
# Id
# 1498       WD      284700
